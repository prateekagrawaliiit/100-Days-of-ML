# %%
import pandas as pd 
from sklearn.model_selection import StratifiedKFold

# %%
df = pd.read_csv('../labeledTrainData.tsv',sep='\t')
df.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
df.loc[:,'kfolds'] = -1
df.sample(frac=1).reset_index(drop=True)
# Out:
#             id  sentiment                                             review  \
# 0      10046_1          0  I wasn't terribly impressed with Dante's 1st s...
# 1      10378_2          0  While the premise behind The House Where Evil ...
# 2      12027_2          0  I saw this movie in the middle of the night, w...
# 3       5093_3          0  I've just visited Russian forum of our TV-chan...
# 4       1524_1          0  Words fail me. This film was extremely difficu...
# ...        ...        ...                                                ...
# 24995   3340_1          0  This is the kind of movie that wants to be goo...
# 24996   7847_3          0  Just recently, I've been obsessing over and an...
# 24997   4318_3          0  I thought this was one of the most depressing ...
# 24998   1812_1          0  Go immediately and rent this movie. It will be...
# 24999    965_4          0  First I liked that movie. It seemed to me a ni...
#
#        kfolds
# 0          -1
# 1          -1
# 2          -1
# 3          -1
# 4          -1
# ...       ...
# 24995      -1
# 24996      -1
# 24997      -1
# 24998      -1
# 24999      -1
#
# [25000 rows x 4 columns]

# %%
y = df.sentiment.values
skf = StratifiedKFold(n_splits=5)
for f,(t_,v_) in enumerate(skf.split(X=df,y=y)):
    df.loc[v_,'kfolds'] = f
    
df.to_csv('train_folds.csv',index=False)

# %%
df.kfolds.value_counts()
# we can see that our folds have been created perfectly
# Out:
# 4    5000
# 3    5000
# 2    5000
# 1    5000
# 0    5000
# Name: kfolds, dtype: int64
