# %%
# Importing the Packages:
import optuna
import pandas as pd
import numpy as np

from sklearn import linear_model
from sklearn import ensemble
from sklearn import datasets
from sklearn import model_selection
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()
df = pd.DataFrame(np.c_[cancer['data'], cancer['target']],
                  columns= np.append(cancer['feature_names'], ['target']))

# %%
X = df.drop('target',axis=1)
y = df.target

# %%
#Step 1. Define an objective function to be maximized.
def objective(trial):

    classifier_name = trial.suggest_categorical("classifier", ["LogReg", "RandomForest"])
    
    # Step 2. Setup values for the hyperparameters:
    if classifier_name == 'LogReg':
        logreg_c = trial.suggest_float("logreg_c", 1e-10, 1e10, log=True)
        classifier_obj = linear_model.LogisticRegression(C=logreg_c)
    else:
        rf_n_estimators = trial.suggest_int("rf_n_estimators", 10, 1000)
        rf_max_depth = trial.suggest_int("rf_max_depth", 2, 32, log=True)
        classifier_obj = ensemble.RandomForestClassifier(
            max_depth=rf_max_depth, n_estimators=rf_n_estimators
        )

    # Step 3: Scoring method:
    score = model_selection.cross_val_score(classifier_obj, X, y, n_jobs=-1, cv=3)
    accuracy = score.mean()
    return accuracy

# Step 4: Running it
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2020-08-19 00:48:54,077] Trial 0 finished with value: 0.9384943841084192 and parameters: {'classifier': 'LogReg', 'logreg_c': 129.95410756932998}. Best is trial 0 with value: 0.9384943841084192.
# [I 2020-08-19 00:48:54,658] Trial 1 finished with value: 0.9367399981435068 and parameters: {'classifier': 'LogReg', 'logreg_c': 71120416.5516676}. Best is trial 0 with value: 0.9384943841084192.
# [I 2020-08-19 00:48:57,396] Trial 2 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 995, 'rf_max_depth': 12}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:48:59,445] Trial 3 finished with value: 0.9437668244685788 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 639, 'rf_max_depth': 2}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:49:00,489] Trial 4 finished with value: 0.9490485472941613 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 396, 'rf_max_depth': 3}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:49:01,970] Trial 5 finished with value: 0.9472848788638263 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 706, 'rf_max_depth': 3}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:49:01,992] Trial 6 finished with value: 0.6274204028589994 and parameters: {'classifier': 'LogReg', 'logreg_c': 1.4491218075830918e-09}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:49:02,013] Trial 7 finished with value: 0.6291840712893344 and parameters: {'classifier': 'LogReg', 'logreg_c': 2.1078037644038892e-09}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:49:02,497] Trial 8 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 222, 'rf_max_depth': 5}. Best is trial 2 with value: 0.9543117051888982.
# [I 2020-08-19 00:49:03,311] Trial 9 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 392, 'rf_max_depth': 26}. Best is trial 9 with value: 0.9560660911538105.
# [I 2020-08-19 00:49:03,494] Trial 10 finished with value: 0.9613385315139701 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 78, 'rf_max_depth': 29}. Best is trial 10 with value: 0.9613385315139701.
# [I 2020-08-19 00:49:03,832] Trial 11 finished with value: 0.9578390420495685 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 129, 'rf_max_depth': 32}. Best is trial 10 with value: 0.9613385315139701.
# [I 2020-08-19 00:49:04,017] Trial 12 finished with value: 0.9613570964448157 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 40, 'rf_max_depth': 31}. Best is trial 12 with value: 0.9613570964448157.
# [I 2020-08-19 00:49:04,090] Trial 13 finished with value: 0.9472848788638263 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 12, 'rf_max_depth': 16}. Best is trial 12 with value: 0.9613570964448157.
# [I 2020-08-19 00:49:04,171] Trial 14 finished with value: 0.9648380209783718 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 14, 'rf_max_depth': 32}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:04,235] Trial 15 finished with value: 0.9419845911073982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 13, 'rf_max_depth': 15}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:04,831] Trial 16 finished with value: 0.9631021999443052 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 263, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:05,400] Trial 17 finished with value: 0.9525480367585631 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 255, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:05,981] Trial 18 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 253, 'rf_max_depth': 7}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:06,850] Trial 19 finished with value: 0.959574863083635 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 431, 'rf_max_depth': 5}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:06,907] Trial 20 finished with value: 0.950784368328228 and parameters: {'classifier': 'LogReg', 'logreg_c': 6644434151.475677}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:07,243] Trial 21 finished with value: 0.9595934280144807 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 145, 'rf_max_depth': 22}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:07,338] Trial 22 finished with value: 0.9578019121878771 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 36, 'rf_max_depth': 20}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:07,814] Trial 23 finished with value: 0.9595934280144807 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 207, 'rf_max_depth': 11}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:08,728] Trial 24 finished with value: 0.9578390420495685 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 334, 'rf_max_depth': 31}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:09,840] Trial 25 finished with value: 0.9613478139793928 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 515, 'rf_max_depth': 10}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:10,108] Trial 26 finished with value: 0.959574863083635 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 117, 'rf_max_depth': 19}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:10,221] Trial 27 finished with value: 0.9525480367585631 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 34, 'rf_max_depth': 5}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:11,077] Trial 28 finished with value: 0.9613385315139701 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 308, 'rf_max_depth': 24}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:11,147] Trial 29 finished with value: 0.9349577647823262 and parameters: {'classifier': 'LogReg', 'logreg_c': 0.0014789454442385593}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:12,103] Trial 30 finished with value: 0.945521210433491 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 521, 'rf_max_depth': 2}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:13,271] Trial 31 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 567, 'rf_max_depth': 10}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:15,435] Trial 32 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 825, 'rf_max_depth': 14}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:16,680] Trial 33 finished with value: 0.9578204771187228 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 470, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:18,217] Trial 34 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 604, 'rf_max_depth': 4}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:20,235] Trial 35 finished with value: 0.959574863083635 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 703, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:20,718] Trial 36 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 181, 'rf_max_depth': 13}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:20,766] Trial 37 finished with value: 0.9472663139329806 and parameters: {'classifier': 'LogReg', 'logreg_c': 779.4930016597187}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:22,945] Trial 38 finished with value: 0.9578204771187228 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 954, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:23,584] Trial 39 finished with value: 0.9578297595841455 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 316, 'rf_max_depth': 18}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:24,473] Trial 40 finished with value: 0.9420124385036664 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 514, 'rf_max_depth': 2}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:25,305] Trial 41 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 351, 'rf_max_depth': 25}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:25,550] Trial 42 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 80, 'rf_max_depth': 30}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:25,914] Trial 43 finished with value: 0.9595841455490578 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 82, 'rf_max_depth': 28}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:26,904] Trial 44 finished with value: 0.9595841455490578 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 432, 'rf_max_depth': 23}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:27,634] Trial 45 finished with value: 0.9578297595841455 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 275, 'rf_max_depth': 11}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:27,688] Trial 46 finished with value: 0.9314675577833472 and parameters: {'classifier': 'LogReg', 'logreg_c': 0.0005132103889982051}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:28,608] Trial 47 finished with value: 0.9613385315139701 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 393, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:29,431] Trial 48 finished with value: 0.9595841455490578 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 391, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:30,699] Trial 49 finished with value: 0.9490392648287385 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 670, 'rf_max_depth': 3}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:31,743] Trial 50 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 470, 'rf_max_depth': 4}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:32,560] Trial 51 finished with value: 0.9613385315139701 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 310, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:33,513] Trial 52 finished with value: 0.9595841455490578 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 370, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:34,997] Trial 53 finished with value: 0.9613385315139701 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 568, 'rf_max_depth': 7}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:35,449] Trial 54 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 154, 'rf_max_depth': 25}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:37,109] Trial 55 finished with value: 0.9578204771187228 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 614, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:38,633] Trial 56 finished with value: 0.9630836350134596 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 574, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:40,494] Trial 57 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 747, 'rf_max_depth': 7}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:41,724] Trial 58 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 556, 'rf_max_depth': 12}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:41,771] Trial 59 finished with value: 0.945521210433491 and parameters: {'classifier': 'LogReg', 'logreg_c': 1081470.2845688444}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:42,908] Trial 60 finished with value: 0.9613478139793931 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 551, 'rf_max_depth': 10}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:43,081] Trial 61 finished with value: 0.9613292490485472 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 72, 'rf_max_depth': 16}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:43,984] Trial 62 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 461, 'rf_max_depth': 10}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:45,177] Trial 63 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 525, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:46,756] Trial 64 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 646, 'rf_max_depth': 4}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:48,246] Trial 65 finished with value: 0.9595841455490578 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 589, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:49,368] Trial 66 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 435, 'rf_max_depth': 32}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:50,756] Trial 67 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 545, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:52,034] Trial 68 finished with value: 0.9578204771187228 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 504, 'rf_max_depth': 11}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:52,617] Trial 69 finished with value: 0.9578297595841455 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 227, 'rf_max_depth': 5}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:53,837] Trial 70 finished with value: 0.9578297595841455 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 480, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:55,321] Trial 71 finished with value: 0.9578390420495685 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 587, 'rf_max_depth': 7}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:56,915] Trial 72 finished with value: 0.9578204771187228 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 636, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:57,942] Trial 73 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 399, 'rf_max_depth': 10}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:58,686] Trial 74 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 278, 'rf_max_depth': 13}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:49:58,760] Trial 75 finished with value: 0.9525573192239859 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 15, 'rf_max_depth': 28}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:00,172] Trial 76 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 561, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:00,332] Trial 77 finished with value: 0.9631021999443052 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 48, 'rf_max_depth': 20}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:00,378] Trial 78 finished with value: 0.9068968718091526 and parameters: {'classifier': 'LogReg', 'logreg_c': 3.4377276339894364e-06}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:00,555] Trial 79 finished with value: 0.9560568086883876 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 55, 'rf_max_depth': 18}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:02,119] Trial 80 finished with value: 0.959574863083635 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 693, 'rf_max_depth': 21}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:02,187] Trial 81 finished with value: 0.9525573192239859 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 16, 'rf_max_depth': 28}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:02,912] Trial 82 finished with value: 0.9595841455490578 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 287, 'rf_max_depth': 24}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:03,188] Trial 83 finished with value: 0.9613292490485472 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 128, 'rf_max_depth': 10}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:03,664] Trial 84 finished with value: 0.9560660911538105 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 237, 'rf_max_depth': 14}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:04,800] Trial 85 finished with value: 0.9595934280144807 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 527, 'rf_max_depth': 7}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:06,066] Trial 86 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 497, 'rf_max_depth': 5}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:06,541] Trial 87 finished with value: 0.959574863083635 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 180, 'rf_max_depth': 31}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:06,831] Trial 88 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 105, 'rf_max_depth': 27}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:07,660] Trial 89 finished with value: 0.9560753736192332 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 324, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:08,740] Trial 90 finished with value: 0.9578204771187228 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 415, 'rf_max_depth': 12}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:10,261] Trial 91 finished with value: 0.9595934280144807 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 604, 'rf_max_depth': 7}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:11,038] Trial 92 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 301, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:11,958] Trial 93 finished with value: 0.9613292490485472 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 354, 'rf_max_depth': 8}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:12,116] Trial 94 finished with value: 0.9578390420495685 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 47, 'rf_max_depth': 6}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:13,261] Trial 95 finished with value: 0.9578297595841455 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 450, 'rf_max_depth': 22}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:13,769] Trial 96 finished with value: 0.9631114824097281 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 195, 'rf_max_depth': 5}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:14,276] Trial 97 finished with value: 0.9507936507936506 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 190, 'rf_max_depth': 5}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:14,634] Trial 98 finished with value: 0.9543117051888982 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 108, 'rf_max_depth': 4}. Best is trial 14 with value: 0.9648380209783718.
# [I 2020-08-19 00:50:15,323] Trial 99 finished with value: 0.9595934280144807 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 250, 'rf_max_depth': 9}. Best is trial 14 with value: 0.9648380209783718.

# %%
# Getting the best trial:
print(f"The best trial is : \n{study.best_trial}")
# >> Output:
#The best trial is : 
#FrozenTrial(number=18, value=0.9631114824097281, datetime_start=datetime.datetime(2020, 8, 16, 14, 24, 37, 407344), datetime_complete=datetime.datetime(2020, 8, 16, 14, 24, 37, 675114), params={'classifier': 'RandomForest', 'rf_n_estimators': 153, 'rf_max_depth': 21},
#distributions={'classifier': CategoricalDistribution(choices=('LogReg', 'RandomForest')), 'rf_n_estimators': IntUniformDistribution(high=1000, low=10, step=1), 'rf_max_depth': IntLogUniformDistribution(high=32, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=18, state=TrialState.COMPLETE)

# Getting the best score:
print(f"The best value is : \n{study.best_value}")
# >> Output:
# 0.9631114824097281

# Getting the best parameters:
print(f"The best parameters are : \n{study.best_params}")
# >> Output:
# {'classifier': 'RandomForest', 'rf_n_estimators': 153, 'rf_max_depth': 21}
# Out:
# The best trial is :
# FrozenTrial(number=14, value=0.9648380209783718, datetime_start=datetime.datetime(2020, 8, 19, 0, 49, 4, 92808), datetime_complete=datetime.datetime(2020, 8, 19, 0, 49, 4, 171497), params={'classifier': 'RandomForest', 'rf_n_estimators': 14, 'rf_max_depth': 32}, distributions={'classifier': CategoricalDistribution(choices=('LogReg', 'RandomForest')), 'rf_n_estimators': IntUniformDistribution(high=1000, low=10, step=1), 'rf_max_depth': IntLogUniformDistribution(high=32, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=14, state=TrialState.COMPLETE)
# The best value is :
# 0.9648380209783718
# The best parameters are :
# {'classifier': 'RandomForest', 'rf_n_estimators': 14, 'rf_max_depth': 32}

# %%
study.trials_dataframe()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0  0.938494 2020-08-19 00:48:52.475049 2020-08-19 00:48:54.076317
# 1        1  0.936740 2020-08-19 00:48:54.081693 2020-08-19 00:48:54.658704
# 2        2  0.954312 2020-08-19 00:48:54.660463 2020-08-19 00:48:57.395732
# 3        3  0.943767 2020-08-19 00:48:57.398756 2020-08-19 00:48:59.445647
# 4        4  0.949049 2020-08-19 00:48:59.448047 2020-08-19 00:49:00.489483
# ..     ...       ...                        ...                        ...
# 95      95  0.957830 2020-08-19 00:50:12.118107 2020-08-19 00:50:13.260875
# 96      96  0.963111 2020-08-19 00:50:13.263478 2020-08-19 00:50:13.769116
# 97      97  0.950794 2020-08-19 00:50:13.771643 2020-08-19 00:50:14.276593
# 98      98  0.954312 2020-08-19 00:50:14.278669 2020-08-19 00:50:14.634611
# 99      99  0.959593 2020-08-19 00:50:14.636708 2020-08-19 00:50:15.322645
#
#           duration params_classifier  params_logreg_c  params_rf_max_depth  \
# 0  00:00:01.601268            LogReg     1.299541e+02                  NaN
# 1  00:00:00.577011            LogReg     7.112042e+07                  NaN
# 2  00:00:02.735269      RandomForest              NaN                 12.0
# 3  00:00:02.046891      RandomForest              NaN                  2.0
# 4  00:00:01.041436      RandomForest              NaN                  3.0
# ..             ...               ...              ...                  ...
# 95 00:00:01.142768      RandomForest              NaN                 22.0
# 96 00:00:00.505638      RandomForest              NaN                  5.0
# 97 00:00:00.504950      RandomForest              NaN                  5.0
# 98 00:00:00.355942      RandomForest              NaN                  4.0
# 99 00:00:00.685937      RandomForest              NaN                  9.0
#
#     params_rf_n_estimators     state
# 0                      NaN  COMPLETE
# 1                      NaN  COMPLETE
# 2                    995.0  COMPLETE
# 3                    639.0  COMPLETE
# 4                    396.0  COMPLETE
# ..                     ...       ...
# 95                   450.0  COMPLETE
# 96                   195.0  COMPLETE
# 97                   190.0  COMPLETE
# 98                   108.0  COMPLETE
# 99                   250.0  COMPLETE
#
# [100 rows x 10 columns]
