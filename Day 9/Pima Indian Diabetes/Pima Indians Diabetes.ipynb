# %%
import pandas as pd
import numpy as np

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('diabetes.csv')
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = dataset.drop('Outcome',axis=1)
X
y = dataset.Outcome
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# define the keras model
model = Sequential()
model.add(Dense(64, input_dim=8, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=100, batch_size=10,verbose=2)
# Out:
# Epoch 1/100
#  - 0s - loss: 1.2332 - accuracy: 0.6081
# Epoch 2/100
#  - 0s - loss: 0.6420 - accuracy: 0.6628
# Epoch 3/100
#  - 0s - loss: 0.6198 - accuracy: 0.6810
# Epoch 4/100
#  - 1s - loss: 0.6340 - accuracy: 0.6719
# Epoch 5/100
#  - 0s - loss: 0.7064 - accuracy: 0.6680
# Epoch 6/100
#  - 0s - loss: 0.5854 - accuracy: 0.7083
# Epoch 7/100
#  - 0s - loss: 0.5742 - accuracy: 0.7044
# Epoch 8/100
#  - 0s - loss: 0.5778 - accuracy: 0.6966
# Epoch 9/100
#  - 0s - loss: 0.5774 - accuracy: 0.7266
# Epoch 10/100
#  - 0s - loss: 0.5671 - accuracy: 0.7135
# Epoch 11/100
#  - 0s - loss: 0.5722 - accuracy: 0.6914
# Epoch 12/100
#  - 0s - loss: 0.5752 - accuracy: 0.6927
# Epoch 13/100
#  - 0s - loss: 0.5855 - accuracy: 0.7057
# Epoch 14/100
#  - 0s - loss: 0.5736 - accuracy: 0.7227
# Epoch 15/100
#  - 0s - loss: 0.5551 - accuracy: 0.7253
# Epoch 16/100
#  - 0s - loss: 0.5525 - accuracy: 0.7318
# Epoch 17/100
#  - 0s - loss: 0.5498 - accuracy: 0.7318
# Epoch 18/100
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 54us/step
# Accuracy: 82.29

# %%
predictions = model.predict_classes(X)

# %%
# predictions

# %%
count=0
for i in range(X.shape[0]):
    
#     print('Actual Outcome {} , Predicted Outcome {}'.format(y.iloc[i],predictions[i][0]))
    if(y.iloc[i]==predictions[i][0]):
        count+=1
    else:
        ;
#         print('Actual Outcome {} , Predicted Outcome {}'.format(y.iloc[i],predictions[i][0]))
 
# print('Accuracy :',count/X.shape[0])
